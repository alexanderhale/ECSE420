# %% [markdown]
# # ECSE 420 - Lab 3
# Drum hit simulation using a grid of finite elements.

# %%
import os
dev_lib_path = !find / -iname 'libdevice'
nvvm_lib_path = !find / -iname 'libnvvm.so'
assert len(dev_lib_path)>0, "Device Lib Missing"
assert len(nvvm_lib_path)>0, "NVVM Missing"
os.environ['NUMBAPRO_LIBDEVICE'] = dev_lib_path[0]
os.environ['NUMBAPRO_NVVM'] = nvvm_lib_path[0]

# %%
from numba import cuda
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Question 1 - Sequential Implementation

# %%
def sequential(N=4, iterations=4):
    u = np.zeros([N, N], dtype = float)
    u1 = u.copy()
    u2 = u.copy()

    G = 0.75
    rho = 0.5
    nu = 0.0002

    # hit = "1" at u(2,2)
    u1[2][2] = 1

    for itera in range(iterations):
        # response 1 to N-2
        for i in range(1, N-1):
            for j in range(1, N-1):
                u[i][j] = ((rho * (u1[i-1][j] + u1[i+1][j] + 
                                  u1[i][j-1] + u1[i][j+1] - 
                                  4*u1[i][j])) + 
                           (2 * u1[i][j]) - ((1 - nu) * u2[i][j]))
                u[i][j] /= (1 + nu)

        # print("pre edges Iteration: {} \nGrid:\n{}\n".format(itera,u))
        # range 1 to N-2
        for x in range(1, N-1):
            ## EDGES
            # left edge = .75 * interior
            u[0][x] = G * u[1][x]
            # right edge
            u[N-1][x] = G * u[N-2][x]
            # top edge
            u[x][0] = G * u[x][1]
            # bottom edge
            u[x][N-1] = G * u[x][N-2]


        # print("pre corners Iteration: {} \nGrid:\n{}\n".format(itera,u))

        ## CORNERS
        # top left
        u[0][0] = G * u[1][0]
        # top right
        u[N-1][0] = G * u[N-2][0]
        # bottom left
        u[0][N-1] = G * u[0][N-2]
        # bottom right
        u[N-1][N-1] = G * u[N-1][N-2]

        u2 = u1.copy()
        u1 = u.copy()

        print(u[2][2])
        print("Iteration: {} \nGrid:\n{}\n".format(itera,u))


sequential(4, 4)
# Out:
# 0.0
# Iteration: 0
# Grid:
# [[0.         0.         0.37492501 0.28119376]
#  [0.         0.         0.49990002 0.37492501]
#  [0.37492501 0.49990002 0.         0.        ]
#  [0.28119376 0.37492501 0.         0.        ]]
#
# -0.49980001999999923
# Iteration: 1
# Grid:
# [[ 0.28113753  0.37485004  0.28113753  0.21085315]
#  [ 0.37485004  0.49980006  0.37485004  0.28113753]
#  [ 0.28113753  0.37485004 -0.49980002 -0.37485001]
#  [ 0.21085315  0.28113753 -0.37485001 -0.28113751]]
#
# 2.9982007234403314e-08
# Iteration: 2
# Grid:
# [[ 4.21621976e-01  5.62162635e-01 -1.63964072e-01 -1.22973054e-01]
#  [ 5.62162635e-01  7.49550180e-01 -2.18618763e-01 -1.63964072e-01]
#  [-1.63964072e-01 -2.18618763e-01  2.99820072e-08  2.24865054e-08]
#  [-1.22973054e-01 -1.63964072e-01  2.24865054e-08  1.68648791e-08]]
#
# 0.28102511495301846
# Iteration: 3
# Grid:
# [[-0.08782031 -0.11709375 -0.12294844 -0.09221133]
#  [-0.11709375 -0.156125   -0.16393126 -0.12294844]
#  [-0.12294844 -0.16393126  0.28102511  0.21076884]
#  [-0.09221133 -0.12294844  0.21076884  0.15807663]]

# %% [markdown]
# # Question 2 - Parallel Implementation #1
# One thread per finite element of the grid

# %%
@cuda.jit
def drum_interior(grid, grid_back1, grid_back2, n, p):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4

    if i not in [0, 3] and j not in [0, 3]:
      # interior node
      grid[i][j] = ((p * (grid_back1[i-1][j] + grid_back1[i+1][j] + 
                          grid_back1[i][j-1] + grid_back1[i][j+1] - 
                          4 * grid_back1[i][j])) + 
                    (2 * grid_back1[i][j]) - ((1 - n) * grid_back2[i][j]))
      grid[i][j] /= (1 + n)

@cuda.jit
def drum_edges(grid, G):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4

    if i == 0 and j in [1, 2]:
      # left edge
      grid[i][j] = G * grid[i + 1][j]
    elif i == 3 and j in [1, 2]:
      # right edge
      grid[i][j] = G * grid[i - 1][j]
    elif j == 0 and i in [1, 2]:
      # top edge
      grid[i][j] = G * grid[i][j + 1]
    elif j == 3 and i in [1, 2]:
      # bottom edge
      grid[i][j] = G * grid[i][j - 1]

@cuda.jit
def drum_corners(grid, G):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4

    if i == 0 and j == 0:
      # top left corner
      grid[i][j] = G * grid[i + 1][j]
    elif i == 0 and j == 3:
      # bottom left corner
      grid[i][j] = G * grid[i][j - 1]
    elif i == 3 and j == 0:
      # top right corner
      grid[i][j] = G * grid[i][j + 1]
    elif i == 3 and j == 3:
      # bottom right corner
      grid[i][j] = G * grid[i][j - 1]

# constant parameters
G = 0.75
n = 0.0002
p = 0.5
gridsize = 4

# grid creation
grid = np.zeros((gridsize, gridsize))
grid_back1 = grid.copy()
grid_back2 = grid.copy()
grid_back1[2][2] = 1   # simulate drum hit at time t-1

# variable parameters
numBlocks = 978
threadsPerBlock = 1000
T = 50

# simulate time progression
for t in range(T):
  # function call (numba performs host -> device -> host memory transfers)
    # required order: interior -> edges -> corners
  drum_interior[numBlocks, threadsPerBlock](grid, grid_back1, grid_back2, n, p)
  drum_edges[numBlocks, threadsPerBlock](grid, G)
  drum_corners[numBlocks, threadsPerBlock](grid, G)
  
  print("u[2, 2] at iteration {}: {}".format(t + 1, grid[2][2]))

  if (t < 3):
    print(grid)
    print()

  grid_back2 = grid_back1.copy()
  grid_back1 = grid.copy()
# Out:
# u[2, 2] at iteration 1: 0.0
# [[0.         0.         0.37492501 0.28119376]
#  [0.         0.         0.49990002 0.37492501]
#  [0.37492501 0.49990002 0.         0.        ]
#  [0.28119376 0.37492501 0.         0.        ]]
#
# u[2, 2] at iteration 2: -0.49980001999999923
# [[ 0.28113753  0.37485004  0.28113753  0.21085315]
#  [ 0.37485004  0.49980006  0.37485004  0.28113753]
#  [ 0.28113753  0.37485004 -0.49980002 -0.37485001]
#  [ 0.21085315  0.28113753 -0.37485001 -0.28113751]]
#
# u[2, 2] at iteration 3: 2.9982007234403314e-08
# [[ 4.21621976e-01  5.62162635e-01 -1.63964072e-01 -1.22973054e-01]
#  [ 5.62162635e-01  7.49550180e-01 -2.18618763e-01 -1.63964072e-01]
#  [-1.63964072e-01 -2.18618763e-01  2.99820072e-08  2.24865054e-08]
#  [-1.22973054e-01 -1.63964072e-01  2.24865054e-08  1.68648791e-08]]
#
# u[2, 2] at iteration 4: 0.2810251149530184
# u[2, 2] at iteration 5: 0.04682818495502672
# u[2, 2] at iteration 6: -0.08778516995465212
# u[2, 2] at iteration 7: -0.32181476130245723
# u[2, 2] at iteration 8: -0.74136664956306
# u[2, 2] at iteration 9: -0.38839948920730266
# u[2, 2] at iteration 10: 0.6652254330040654
# u[2, 2] at iteration 11: 0.7787261426358246
# u[2, 2] at iteration 12: -0.22371278398803726
# u[2, 2] at iteration 13: -0.5139857688941788
# u[2, 2] at iteration 14: 0.3315687356910853
# u[2, 2] at iteration 15: 0.7216416509417185
# u[2, 2] at iteration 16: 0.16843621887136329
# u[2, 2] at iteration 17: -0.28548607266696807
# u[2, 2] at iteration 18: -0.4078320015272444
# u[2, 2] at iteration 19: -0.563128497465155
# u[2, 2] at iteration 20: -0.2835166141928366
# u[2, 2] at iteration 21: 0.4472320260386376
# u[2, 2] at iteration 22: 0.39596970515004054
# u[2, 2] at iteration 23: -0.496526695683186
# u[2, 2] at iteration 24: -0.5256373939774961
# u[2, 2] at iteration 25: 0.5760366497416338
# u[2, 2] at iteration 26: 0.9926034468428319
# u[2, 2] at iteration 27: 0.1908710314349021
# u[2, 2] at iteration 28: -0.4025014078396819
# u[2, 2] at iteration 29: -0.27847620339368123
# u[2, 2] at iteration 30: -0.1845074875605142
# u[2, 2] at iteration 31: -0.11426122887022694
# u[2, 2] at iteration 32: 0.18264642990383687
# u[2, 2] at iteration 33: -0.006543707448174733
# u[2, 2] at iteration 34: -0.7084566412480809
# u[2, 2] at iteration 35: -0.5236507316698267
# u[2, 2] at iteration 36: 0.6606126905303338
# u[2, 2] at iteration 37: 1.011229967369607
# u[2, 2] at iteration 38: 0.06969105659603876
# u[2, 2] at iteration 39: -0.47278567809030636
# u[2, 2] at iteration 40: -0.007734276427380817
# u[2, 2] at iteration 41: 0.29785640628725146
# u[2, 2] at iteration 42: 0.08372459141656625
# u[2, 2] at iteration 43: -0.05317669912526922
# u[2, 2] at iteration 44: -0.29017494547559003
# u[2, 2] at iteration 45: -0.7503066244101299
# u[2, 2] at iteration 46: -0.4712290728134359
# u[2, 2] at iteration 47: 0.5823734455406359
# u[2, 2] at iteration 48: 0.7847448542273362
# u[2, 2] at iteration 49: -0.18063500872074204
# u[2, 2] at iteration 50: -0.5312129608171092

# %% [markdown]
# # Question 3 - Parallel Implementation #3
# Variable number of finite elements per thread. Output at [N/2, N/2] for 50 iterations is shown below (for comparison with posted file).

# %%
@cuda.jit
def drum_interiorMult(grid, grid_back1, grid_back2, n, p, gridsize, elementsPerThread, threadsRequired):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < threadsRequired:
    for iteration in range(elementsPerThread):
      # updating on adjacent nodes isn't a problem because we're using the history grids only
      realIdx = idx * elementsPerThread + iteration

      if realIdx < gridsize * gridsize:
        j = realIdx // gridsize
        i = realIdx % gridsize

        if i != 0 and j != 0 and i != gridsize - 1 and j != gridsize - 1:
          # interior node
          grid[i][j] = ((p * (grid_back1[i-1][j] + grid_back1[i+1][j] + 
                              grid_back1[i][j-1] + grid_back1[i][j+1] - 
                              4 * grid_back1[i][j])) + 
                        (2 * grid_back1[i][j]) - ((1 - n) * grid_back2[i][j]))
          grid[i][j] /= (1 + n)

@cuda.jit
def drum_edgesMult(grid, G, gridsize, elementsPerThread, threadsRequired):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < threadsRequired:
    for iteration in range(elementsPerThread):
      # updating on adjacent nodes isn't a problem because we're using the history grids only
      realIdx = idx * elementsPerThread + iteration

      if realIdx < gridsize * gridsize:
        j = realIdx // gridsize
        i = realIdx % gridsize

        if i == 0 and j in [1, 2]:
          # left edge
          grid[i][j] = G * grid[i + 1][j]
        elif i == 3 and j in [1, 2]:
          # right edge
          grid[i][j] = G * grid[i - 1][j]
        elif j == 0 and i in [1, 2]:
          # top edge
          grid[i][j] = G * grid[i][j + 1]
        elif j == 3 and i in [1, 2]:
          # bottom edge
          grid[i][j] = G * grid[i][j - 1]

@cuda.jit
def drum_cornersMult(grid, G, gridsize, elementsPerThread, threadsRequired):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < threadsRequired:
    for iteration in range(elementsPerThread):
      # updating on adjacent nodes isn't a problem because we're using the history grids only
      realIdx = idx * elementsPerThread + iteration

      if realIdx < gridsize * gridsize:
        j = realIdx // gridsize
        i = realIdx % gridsize

        if i == 0 and j == 0:
          # top left corner
          grid[i][j] = G * grid[i + 1][j]
        elif i == 0 and j == 3:
          # bottom left corner
          grid[i][j] = G * grid[i][j - 1]
        elif i == 3 and j == 0:
          # top right corner
          grid[i][j] = G * grid[i][j + 1]
        elif i == 3 and j == 3:
          # bottom right corner
          grid[i][j] = G * grid[i][j - 1]

# constant parameters
G = 0.75
n = 0.0002
p = 0.5
gridsize = 512

# grid creation
grid = np.zeros((gridsize, gridsize))
grid_back1 = grid.copy()
grid_back2 = grid.copy()
grid_back1[gridsize // 2][gridsize // 2] = 1   # simulate drum hit at time t-1

# variable parameters
numBlocks = 978
threadsPerBlock = 1000
elementsPerThread = 16
T = 50

threadsRequired = math.ceil((gridsize * gridsize) / elementsPerThread)

# simulate time progression
for t in range(T):
  # function call (numba performs host -> device -> host memory transfers)
    # required order: interior -> edges -> corners
  drum_interiorMult[numBlocks, threadsPerBlock](grid, grid_back1, grid_back2, n, p, gridsize, elementsPerThread, threadsRequired)
  drum_edgesMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)
  drum_cornersMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)
  
  print("Iteration {}: {}".format(t + 1, grid[gridsize // 2][gridsize // 2]))

  grid_back2 = grid_back1.copy()
  grid_back1 = grid.copy()
# Out:
# Iteration 1: 0.0
# Iteration 2: 3.998400479824981e-08
# Iteration 3: 0.0
# Iteration 4: 0.24980013992803154
# Iteration 5: 0.0
# Iteration 6: 8.9892080370116e-08
# Iteration 7: 0.0
# Iteration 8: 0.14040029222121936
# Iteration 9: 0.0
# Iteration 10: 1.403440891682952e-07
# Iteration 11: 0.0
# Iteration 12: 0.09742231969133452
# Iteration 13: 0.0
# Iteration 14: 1.9087120709162718e-07
# Iteration 15: 0.0
# Iteration 16: 0.0745294056393437
# Iteration 17: 0.0
# Iteration 18: 2.413783011458448e-07
# Iteration 19: 0.0
# Iteration 20: 0.060320634512427584
# Iteration 21: 0.0
# Iteration 22: 2.918343471751079e-07
# Iteration 23: 0.0
# Iteration 24: 0.050645649253699805
# Iteration 25: 0.0
# Iteration 26: 3.4222637009984303e-07
# Iteration 27: 0.0
# Iteration 28: 0.0436341257299501
# Iteration 29: 0.0
# Iteration 30: 3.925480441346873e-07
# Iteration 31: 0.0
# Iteration 32: 0.03831973287361857
# Iteration 33: 0.0
# Iteration 34: 4.4279595196121775e-07
# Iteration 35: 0.0
# Iteration 36: 0.03415301791490642
# Iteration 37: 0.0
# Iteration 38: 4.929681108493421e-07
# Iteration 39: 0.0
# Iteration 40: 0.030798546140529577
# Iteration 41: 0.0
# Iteration 42: 5.430633118003722e-07
# Iteration 43: 0.0
# Iteration 44: 0.028039967254005736
# Iteration 45: 0.0
# Iteration 46: 5.930807933462375e-07
# Iteration 47: 0.0
# Iteration 48: 0.02573148721548688
# Iteration 49: 0.0
# Iteration 50: 6.43020065892496e-07

# %% [markdown]
# ### Comparison with Previous Implementations
# Compare implementation #3 with implementations #1 and #2 to ensure that results match.

# %%
# constant parameters
G = 0.75
n = 0.0002
p = 0.5
gridsize = 4

# grid creation
grid = np.zeros((gridsize, gridsize))
grid_back1 = grid.copy()
grid_back2 = grid.copy()
grid_back1[gridsize // 2][gridsize // 2] = 1   # simulate drum hit at time t-1

# variable parameters
numBlocks = 978
threadsPerBlock = 1000
elementsPerThread = 16
T = 50

threadsRequired = math.ceil((gridsize * gridsize) / elementsPerThread)

# simulate time progression
for t in range(T):
  # function call (numba performs host -> device -> host memory transfers)
    # required order: interior -> edges -> corners
  drum_interiorMult[numBlocks, threadsPerBlock](grid, grid_back1, grid_back2, n, p, gridsize, elementsPerThread, threadsRequired)
  drum_edgesMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)
  drum_cornersMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)
  
  print("Iteration {}: {}".format(t + 1, grid[gridsize // 2][gridsize // 2]))

  if (t < 3):
    print(grid)

  grid_back2 = grid_back1.copy()
  grid_back1 = grid.copy()
# Out:
# Iteration 1: 0.0
# [[0.         0.         0.37492501 0.28119376]
#  [0.         0.         0.49990002 0.37492501]
#  [0.37492501 0.49990002 0.         0.        ]
#  [0.28119376 0.37492501 0.         0.        ]]
# Iteration 2: -0.49980001999999923
# [[ 0.28113753  0.37485004  0.28113753  0.21085315]
#  [ 0.37485004  0.49980006  0.37485004  0.28113753]
#  [ 0.28113753  0.37485004 -0.49980002 -0.37485001]
#  [ 0.21085315  0.28113753 -0.37485001 -0.28113751]]
# Iteration 3: 2.9982007234403314e-08
# [[ 4.21621976e-01  5.62162635e-01 -1.63964072e-01 -1.22973054e-01]
#  [ 5.62162635e-01  7.49550180e-01 -2.18618763e-01 -1.63964072e-01]
#  [-1.63964072e-01 -2.18618763e-01  2.99820072e-08  2.24865054e-08]
#  [-1.22973054e-01 -1.63964072e-01  2.24865054e-08  1.68648791e-08]]
# Iteration 4: 0.2810251149530184
# Iteration 5: 0.04682818495502672
# Iteration 6: -0.08778516995465212
# Iteration 7: -0.32181476130245723
# Iteration 8: -0.74136664956306
# Iteration 9: -0.38839948920730266
# Iteration 10: 0.6652254330040654
# Iteration 11: 0.7787261426358246
# Iteration 12: -0.22371278398803726
# Iteration 13: -0.5139857688941788
# Iteration 14: 0.3315687356910853
# Iteration 15: 0.7216416509417185
# Iteration 16: 0.16843621887136329
# Iteration 17: -0.28548607266696807
# Iteration 18: -0.4078320015272444
# Iteration 19: -0.563128497465155
# Iteration 20: -0.2835166141928366
# Iteration 21: 0.4472320260386376
# Iteration 22: 0.39596970515004054
# Iteration 23: -0.496526695683186
# Iteration 24: -0.5256373939774961
# Iteration 25: 0.5760366497416338
# Iteration 26: 0.9926034468428319
# Iteration 27: 0.1908710314349021
# Iteration 28: -0.4025014078396819
# Iteration 29: -0.27847620339368123
# Iteration 30: -0.1845074875605142
# Iteration 31: -0.11426122887022694
# Iteration 32: 0.18264642990383687
# Iteration 33: -0.006543707448174733
# Iteration 34: -0.7084566412480809
# Iteration 35: -0.5236507316698267
# Iteration 36: 0.6606126905303338
# Iteration 37: 1.011229967369607
# Iteration 38: 0.06969105659603876
# Iteration 39: -0.47278567809030636
# Iteration 40: -0.007734276427380817
# Iteration 41: 0.29785640628725146
# Iteration 42: 0.08372459141656625
# Iteration 43: -0.05317669912526922
# Iteration 44: -0.29017494547559003
# Iteration 45: -0.7503066244101299
# Iteration 46: -0.4712290728134359
# Iteration 47: 0.5823734455406359
# Iteration 48: 0.7847448542273362
# Iteration 49: -0.18063500872074204
# Iteration 50: -0.5312129608171092

# %% [markdown]
# ### Performance Measurements

# %%
import time

# constant parameters
G = 0.75
n = 0.0002
p = 0.5
gridsize = 512
T = 500

# grid creation
grid = np.zeros((gridsize, gridsize))
grid_back1 = grid.copy()
grid_back2 = grid.copy()
grid_back1[gridsize // 2][gridsize // 2] = 1   # simulate drum hit at time t-1

for numBlocks in [1, 4, 8, 32, 128, 512, 2048]:
  for threadsPerBlock in [1, 4, 16, 64, 256, 1024]:
    for elementsPerThread in [1, 4, 16, 64, 256]:
      start = time.time()
      threadsRequired = math.ceil((gridsize * gridsize) / elementsPerThread)

      # simulate time progression
      for t in range(T):
        # function call (numba performs host -> device -> host memory transfers)
          # required order: interior -> edges -> corners
        drum_interiorMult[numBlocks, threadsPerBlock](grid, grid_back1, grid_back2, n, p, gridsize, elementsPerThread, threadsRequired)
        drum_edgesMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)
        drum_cornersMult[numBlocks, threadsPerBlock](grid, G, gridsize, elementsPerThread, threadsRequired)

        grid_back2 = grid_back1.copy()
        grid_back1 = grid.copy()
      
      print("Runtime for {} blocks, {} threads, {} elements: {}".format(numBlocks, threadsPerBlock, elementsPerThread, time.time() - start))
# Out:
# Runtime for 1 blocks, 1 threads, 1 elements: 4.120593786239624
# Runtime for 1 blocks, 1 threads, 4 elements: 4.085301876068115
# Runtime for 1 blocks, 1 threads, 16 elements: 4.075458288192749
# Runtime for 1 blocks, 1 threads, 64 elements: 4.0888471603393555
# Runtime for 1 blocks, 1 threads, 256 elements: 4.232138156890869
# Runtime for 1 blocks, 4 threads, 1 elements: 4.0656092166900635
# Runtime for 1 blocks, 4 threads, 4 elements: 4.0501868724823
# Runtime for 1 blocks, 4 threads, 16 elements: 4.025616645812988
# Runtime for 1 blocks, 4 threads, 64 elements: 4.126385927200317
# Runtime for 1 blocks, 4 threads, 256 elements: 4.3583338260650635
# Runtime for 1 blocks, 16 threads, 1 elements: 4.064435958862305
# Runtime for 1 blocks, 16 threads, 4 elements: 4.055553197860718
# Runtime for 1 blocks, 16 threads, 16 elements: 4.0937628746032715
# Runtime for 1 blocks, 16 threads, 64 elements: 4.104035139083862
# Runtime for 1 blocks, 16 threads, 256 elements: 4.379432678222656
# Runtime for 1 blocks, 64 threads, 1 elements: 4.08608603477478
# Runtime for 1 blocks, 64 threads, 4 elements: 4.043533086776733
# Runtime for 1 blocks, 64 threads, 16 elements: 4.049347400665283
# Runtime for 1 blocks, 64 threads, 64 elements: 4.097777605056763
# Runtime for 1 blocks, 64 threads, 256 elements: 4.397683143615723
# Runtime for 1 blocks, 256 threads, 1 elements: 4.08132791519165
# Runtime for 1 blocks, 256 threads, 4 elements: 4.070029973983765
# Runtime for 1 blocks, 256 threads, 16 elements: 4.094501733779907
# Runtime for 1 blocks, 256 threads, 64 elements: 4.155843019485474
# Runtime for 1 blocks, 256 threads, 256 elements: 4.452999591827393
# Runtime for 1 blocks, 1024 threads, 1 elements: 4.085408926010132
# Runtime for 1 blocks, 1024 threads, 4 elements: 4.0904011726379395
# Runtime for 1 blocks, 1024 threads, 16 elements: 4.172957420349121
# Runtime for 1 blocks, 1024 threads, 64 elements: 4.354455232620239
# Runtime for 1 blocks, 1024 threads, 256 elements: 5.101371765136719
# Runtime for 4 blocks, 1 threads, 1 elements: 4.085557460784912
# Runtime for 4 blocks, 1 threads, 4 elements: 4.076764345169067
# Runtime for 4 blocks, 1 threads, 16 elements: 4.079516887664795
# Runtime for 4 blocks, 1 threads, 64 elements: 4.089205503463745
# Runtime for 4 blocks, 1 threads, 256 elements: 4.3823113441467285
# Runtime for 4 blocks, 4 threads, 1 elements: 4.065147876739502
# Runtime for 4 blocks, 4 threads, 4 elements: 4.0972607135772705
# Runtime for 4 blocks, 4 threads, 16 elements: 4.0973639488220215
# Runtime for 4 blocks, 4 threads, 64 elements: 4.114279508590698
# Runtime for 4 blocks, 4 threads, 256 elements: 4.3740410804748535
# Runtime for 4 blocks, 16 threads, 1 elements: 4.082698345184326
# Runtime for 4 blocks, 16 threads, 4 elements: 4.109398603439331
# Runtime for 4 blocks, 16 threads, 16 elements: 4.074307203292847
# Runtime for 4 blocks, 16 threads, 64 elements: 4.111696481704712
# Runtime for 4 blocks, 16 threads, 256 elements: 4.392357110977173
# Runtime for 4 blocks, 64 threads, 1 elements: 4.072792291641235
# Runtime for 4 blocks, 64 threads, 4 elements: 4.06978964805603
# Runtime for 4 blocks, 64 threads, 16 elements: 4.110761880874634
# Runtime for 4 blocks, 64 threads, 64 elements: 4.193701982498169
# Runtime for 4 blocks, 64 threads, 256 elements: 4.41459321975708
# Runtime for 4 blocks, 256 threads, 1 elements: 4.058751106262207
# Runtime for 4 blocks, 256 threads, 4 elements: 4.0919013023376465
# Runtime for 4 blocks, 256 threads, 16 elements: 4.086574077606201
# Runtime for 4 blocks, 256 threads, 64 elements: 4.14447546005249
# Runtime for 4 blocks, 256 threads, 256 elements: 4.502148628234863
# Runtime for 4 blocks, 1024 threads, 1 elements: 4.0694780349731445
# Runtime for 4 blocks, 1024 threads, 4 elements: 4.067419052124023
# Runtime for 4 blocks, 1024 threads, 16 elements: 4.123610019683838
# Runtime for 4 blocks, 1024 threads, 64 elements: 4.336656093597412
# Runtime for 4 blocks, 1024 threads, 256 elements: 5.056781768798828
# Runtime for 8 blocks, 1 threads, 1 elements: 4.058002471923828
# Runtime for 8 blocks, 1 threads, 4 elements: 4.119375944137573
# Runtime for 8 blocks, 1 threads, 16 elements: 4.105259418487549
# Runtime for 8 blocks, 1 threads, 64 elements: 4.124357223510742
# Runtime for 8 blocks, 1 threads, 256 elements: 4.388477563858032
# Runtime for 8 blocks, 4 threads, 1 elements: 4.125362396240234
# Runtime for 8 blocks, 4 threads, 4 elements: 4.1025800704956055
# Runtime for 8 blocks, 4 threads, 16 elements: 4.112857818603516
# Runtime for 8 blocks, 4 threads, 64 elements: 4.136270523071289
# Runtime for 8 blocks, 4 threads, 256 elements: 4.400686025619507
# Runtime for 8 blocks, 16 threads, 1 elements: 4.089152574539185
# Runtime for 8 blocks, 16 threads, 4 elements: 4.079887628555298
# Runtime for 8 blocks, 16 threads, 16 elements: 4.087887287139893
# Runtime for 8 blocks, 16 threads, 64 elements: 4.156332015991211
# Runtime for 8 blocks, 16 threads, 256 elements: 4.487285375595093
# Runtime for 8 blocks, 64 threads, 1 elements: 4.178492546081543
# Runtime for 8 blocks, 64 threads, 4 elements: 4.110201358795166
# Runtime for 8 blocks, 64 threads, 16 elements: 4.094444274902344
# Runtime for 8 blocks, 64 threads, 64 elements: 4.149348497390747
# Runtime for 8 blocks, 64 threads, 256 elements: 4.461828708648682
# Runtime for 8 blocks, 256 threads, 1 elements: 4.082500696182251
# Runtime for 8 blocks, 256 threads, 4 elements: 4.0892791748046875
# Runtime for 8 blocks, 256 threads, 16 elements: 4.118352890014648
# Runtime for 8 blocks, 256 threads, 64 elements: 4.186319351196289
# Runtime for 8 blocks, 256 threads, 256 elements: 4.5675368309021
# Runtime for 8 blocks, 1024 threads, 1 elements: 4.119609594345093
# Runtime for 8 blocks, 1024 threads, 4 elements: 4.120394229888916
# Runtime for 8 blocks, 1024 threads, 16 elements: 4.178858041763306
# Runtime for 8 blocks, 1024 threads, 64 elements: 4.3385703563690186
# Runtime for 8 blocks, 1024 threads, 256 elements: 5.101961135864258
# Runtime for 32 blocks, 1 threads, 1 elements: 4.097242832183838
# Runtime for 32 blocks, 1 threads, 4 elements: 4.119197368621826
# Runtime for 32 blocks, 1 threads, 16 elements: 4.095983266830444
# Runtime for 32 blocks, 1 threads, 64 elements: 4.1653547286987305
# Runtime for 32 blocks, 1 threads, 256 elements: 4.399910926818848
# Runtime for 32 blocks, 4 threads, 1 elements: 4.119973182678223
# Runtime for 32 blocks, 4 threads, 4 elements: 4.132287502288818
# Runtime for 32 blocks, 4 threads, 16 elements: 4.09825587272644
# Runtime for 32 blocks, 4 threads, 64 elements: 4.18567681312561
# Runtime for 32 blocks, 4 threads, 256 elements: 4.395756006240845
# Runtime for 32 blocks, 16 threads, 1 elements: 4.096424579620361
# Runtime for 32 blocks, 16 threads, 4 elements: 4.10567831993103
# Runtime for 32 blocks, 16 threads, 16 elements: 4.085651159286499
# Runtime for 32 blocks, 16 threads, 64 elements: 4.163074970245361
# Runtime for 32 blocks, 16 threads, 256 elements: 4.49842643737793
# Runtime for 32 blocks, 64 threads, 1 elements: 4.183630704879761
# Runtime for 32 blocks, 64 threads, 4 elements: 4.128951072692871
# Runtime for 32 blocks, 64 threads, 16 elements: 4.10266637802124
# Runtime for 32 blocks, 64 threads, 64 elements: 4.152173280715942
# Runtime for 32 blocks, 64 threads, 256 elements: 4.467738151550293
# Runtime for 32 blocks, 256 threads, 1 elements: 4.076934576034546
# Runtime for 32 blocks, 256 threads, 4 elements: 4.112537384033203
# Runtime for 32 blocks, 256 threads, 16 elements: 4.11199951171875
# Runtime for 32 blocks, 256 threads, 64 elements: 4.170028924942017
# Runtime for 32 blocks, 256 threads, 256 elements: 4.504545211791992
# Runtime for 32 blocks, 1024 threads, 1 elements: 4.119572401046753
# Runtime for 32 blocks, 1024 threads, 4 elements: 4.116295337677002
# Runtime for 32 blocks, 1024 threads, 16 elements: 4.1590752601623535
# Runtime for 32 blocks, 1024 threads, 64 elements: 4.3749659061431885
# Runtime for 32 blocks, 1024 threads, 256 elements: 5.135992527008057
# Runtime for 128 blocks, 1 threads, 1 elements: 4.119977712631226
# Runtime for 128 blocks, 1 threads, 4 elements: 4.11701226234436
# Runtime for 128 blocks, 1 threads, 16 elements: 4.137515068054199
# Runtime for 128 blocks, 1 threads, 64 elements: 4.1920928955078125
# Runtime for 128 blocks, 1 threads, 256 elements: 4.428011178970337
# Runtime for 128 blocks, 4 threads, 1 elements: 4.137946367263794
# Runtime for 128 blocks, 4 threads, 4 elements: 4.152251958847046
# Runtime for 128 blocks, 4 threads, 16 elements: 4.099976062774658
# Runtime for 128 blocks, 4 threads, 64 elements: 4.151238918304443
# Runtime for 128 blocks, 4 threads, 256 elements: 4.403345346450806
# Runtime for 128 blocks, 16 threads, 1 elements: 4.10371732711792
# Runtime for 128 blocks, 16 threads, 4 elements: 4.093205213546753
# Runtime for 128 blocks, 16 threads, 16 elements: 4.1047587394714355
# Runtime for 128 blocks, 16 threads, 64 elements: 4.198277950286865
# Runtime for 128 blocks, 16 threads, 256 elements: 4.489398956298828
# Runtime for 128 blocks, 64 threads, 1 elements: 4.100592851638794
# Runtime for 128 blocks, 64 threads, 4 elements: 4.126346588134766
# Runtime for 128 blocks, 64 threads, 16 elements: 4.110357999801636
# Runtime for 128 blocks, 64 threads, 64 elements: 4.169250249862671
# Runtime for 128 blocks, 64 threads, 256 elements: 4.4764039516448975
# Runtime for 128 blocks, 256 threads, 1 elements: 4.1213953495025635
# Runtime for 128 blocks, 256 threads, 4 elements: 4.152178764343262
# Runtime for 128 blocks, 256 threads, 16 elements: 4.1420063972473145
# Runtime for 128 blocks, 256 threads, 64 elements: 4.241227626800537
# Runtime for 128 blocks, 256 threads, 256 elements: 4.504751920700073
# Runtime for 128 blocks, 1024 threads, 1 elements: 4.11666464805603
# Runtime for 128 blocks, 1024 threads, 4 elements: 4.203028917312622
# Runtime for 128 blocks, 1024 threads, 16 elements: 4.293935060501099
# Runtime for 128 blocks, 1024 threads, 64 elements: 4.465434789657593
# Runtime for 128 blocks, 1024 threads, 256 elements: 5.101236581802368
# Runtime for 512 blocks, 1 threads, 1 elements: 4.130258321762085
# Runtime for 512 blocks, 1 threads, 4 elements: 4.118697881698608
# Runtime for 512 blocks, 1 threads, 16 elements: 4.145933151245117
# Runtime for 512 blocks, 1 threads, 64 elements: 4.198277950286865
# Runtime for 512 blocks, 1 threads, 256 elements: 4.53870701789856
# Runtime for 512 blocks, 4 threads, 1 elements: 4.144097089767456
# Runtime for 512 blocks, 4 threads, 4 elements: 4.1045982837677
# Runtime for 512 blocks, 4 threads, 16 elements: 4.134463787078857
# Runtime for 512 blocks, 4 threads, 64 elements: 4.162224054336548
# Runtime for 512 blocks, 4 threads, 256 elements: 4.469429969787598
# Runtime for 512 blocks, 16 threads, 1 elements: 4.1219165325164795
# Runtime for 512 blocks, 16 threads, 4 elements: 4.162867069244385
# Runtime for 512 blocks, 16 threads, 16 elements: 4.179474830627441
# Runtime for 512 blocks, 16 threads, 64 elements: 4.177767753601074
# Runtime for 512 blocks, 16 threads, 256 elements: 4.498849630355835
# Runtime for 512 blocks, 64 threads, 1 elements: 4.111173868179321
# Runtime for 512 blocks, 64 threads, 4 elements: 4.185783863067627
# Runtime for 512 blocks, 64 threads, 16 elements: 4.2094056606292725
# Runtime for 512 blocks, 64 threads, 64 elements: 4.247327566146851
# Runtime for 512 blocks, 64 threads, 256 elements: 4.611433267593384
# Runtime for 512 blocks, 256 threads, 1 elements: 4.186459064483643
# Runtime for 512 blocks, 256 threads, 4 elements: 4.228179216384888
# Runtime for 512 blocks, 256 threads, 16 elements: 4.252619743347168
# Runtime for 512 blocks, 256 threads, 64 elements: 4.234444618225098
# Runtime for 512 blocks, 256 threads, 256 elements: 4.59470534324646
# Runtime for 512 blocks, 1024 threads, 1 elements: 4.2836549282073975
# Runtime for 512 blocks, 1024 threads, 4 elements: 4.239834785461426
# Runtime for 512 blocks, 1024 threads, 16 elements: 4.22218918800354
# Runtime for 512 blocks, 1024 threads, 64 elements: 4.47139835357666
# Runtime for 512 blocks, 1024 threads, 256 elements: 5.181542158126831
# Runtime for 2048 blocks, 1 threads, 1 elements: 4.198734760284424
# Runtime for 2048 blocks, 1 threads, 4 elements: 4.222890615463257
# Runtime for 2048 blocks, 1 threads, 16 elements: 4.2492876052856445
# Runtime for 2048 blocks, 1 threads, 64 elements: 4.5041704177856445
# Runtime for 2048 blocks, 1 threads, 256 elements: 4.919832229614258
# Runtime for 2048 blocks, 4 threads, 1 elements: 4.195805788040161
# Runtime for 2048 blocks, 4 threads, 4 elements: 4.185166597366333
# Runtime for 2048 blocks, 4 threads, 16 elements: 4.214757204055786
# Runtime for 2048 blocks, 4 threads, 64 elements: 4.343350648880005
# Runtime for 2048 blocks, 4 threads, 256 elements: 4.647517681121826
# Runtime for 2048 blocks, 16 threads, 1 elements: 4.268779754638672
# Runtime for 2048 blocks, 16 threads, 4 elements: 4.152869462966919
# Runtime for 2048 blocks, 16 threads, 16 elements: 4.162823438644409
# Runtime for 2048 blocks, 16 threads, 64 elements: 4.197442054748535
# Runtime for 2048 blocks, 16 threads, 256 elements: 4.467650413513184
# Runtime for 2048 blocks, 64 threads, 1 elements: 4.1387574672698975
# Runtime for 2048 blocks, 64 threads, 4 elements: 4.1514668464660645
# Runtime for 2048 blocks, 64 threads, 16 elements: 4.150150537490845
# Runtime for 2048 blocks, 64 threads, 64 elements: 4.238179445266724
# Runtime for 2048 blocks, 64 threads, 256 elements: 4.499445915222168
# Runtime for 2048 blocks, 256 threads, 1 elements: 4.149371862411499
# Runtime for 2048 blocks, 256 threads, 4 elements: 4.1354451179504395
# Runtime for 2048 blocks, 256 threads, 16 elements: 4.134158372879028
# Runtime for 2048 blocks, 256 threads, 64 elements: 4.216689109802246
# Runtime for 2048 blocks, 256 threads, 256 elements: 4.564484119415283
# Runtime for 2048 blocks, 1024 threads, 1 elements: 4.168596506118774
# Runtime for 2048 blocks, 1024 threads, 4 elements: 4.219952344894409
# Runtime for 2048 blocks, 1024 threads, 16 elements: 4.155189752578735
# Runtime for 2048 blocks, 1024 threads, 64 elements: 4.378410339355469
# Runtime for 2048 blocks, 1024 threads, 256 elements: 5.119558334350586
